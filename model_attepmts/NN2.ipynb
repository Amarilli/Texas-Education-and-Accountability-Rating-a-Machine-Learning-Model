# %%
import pandas as pd
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# %%
districts = pd.read_csv('Resources/tor20.21.csv')
staar = pd.read_csv('Resources/staar20.21.cleaned.csv')
teacher = pd.read_csv('Resources/teachers_scores20_21.csv')
all_info = pd.read_csv('Resources/DISTRICTS_INFO_2020.21.csv')

# %%
all_info.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'DISTRICT NUMBER',
#  'COUNTY NUMBER AND NAME',
#  'EDUCATION SERVICE CENTER REGION',
#  'DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL NUMBER OF SCHOOLS',
#  'TOTAL STUDENTS',
#  'STUDENTS: % AFRICAN AMERICAN',
#  'STUDENTS: % HISPANIC',
#  'STUDENTS: % WHITE',
#  'STUDENTS: % AMERICAN INDIAN',
#  'STUDENTS: % ASIAN',
#  'STUDENTS: % PACIFIC ISLANDER',
#  'STUDENTS: % TWO OR MORE RACES',
#  'STUDENTS: % ECONOMICALLY DISADVANTAGED',
#  'STUDENTS: % ENGLISH LEARNERS (EL)',
#  'STUDENTS: % SPECIAL EDUCATION',
#  'STUDENTS: % BILINGUAL/ESL EDUCATION',
#  'STUDENTS: % CAREER & TECHNICAL EDUCATION',
#  'STUDENTS: % GIFTED & TALENTED EDUCATION',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
#  ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
#  'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
#  'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
#  'SAT-AVERAGE SCORE (2021-2020)',
#  'ACT-AVERAGE SCORE (2021-2020)',
#  'TOTAL STAFF FTE',
#  'TOTAL TEACHER FTE',
#  'STAFF: % CENTRAL ADMINISTRATIVE',
#  'STAFF: % SCHOOL ADMINISTRATIVE',
#  'STAFF: % PROFESSIONAL SUPPORT',
#  'STAFF: % TEACHERS',
#  'STAFF: % EDUCATIONAL AIDES',
#  'STAFF: % AUXILIARY',
#  'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
#  'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
#  'AVERAGE SALARY: PROFESSIONAL SUPPORT',
#  'AVERAGE SALARY: TEACHER',
#  'STAFF: % MINORITY',
#  'NUMBER OF STUDENTS PER TOTAL STAFF',
#  'NUMBER OF STUDENTS PER TEACHER',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'TEACHER: % WITH ADVANCED DEGREES',
#  'TEACHER: TURNOVER RATE',
#  'TEACHER: % AFRICAN AMERICAN',
#  'TEACHER: % HISPANIC',
#  'TEACHER: % WHITE',
#  'TEACHER: % AMERICAN INDIAN',
#  'TEACHER: % ASIAN',
#  'TEACHER: % PACIFIC ISLANDER',
#  'TEACHER: % TWO OR MORE RACES',
#  'TEACHER: % REGULAR EDUCATION',
#  'TEACHER: % SPECIAL EDUCATION',
#  'TEACHER: % COMPENSATORY EDUCATION',
#  'TEACHER: % BILINGUAL/ESL EDUCATION',
#  'TEACHER: % CAREER & TECHNICAL EDUCATION',
#  'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
#  'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
#  'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
#  'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
#  'Total OPERATING AND OTHER REVENUE PER PUPIL',
#  'Total OPERATING REVENUE (2020-21)',
#  'REVENUE: % STATE',
#  'REVENUE: % LOCAL AND OTHER',
#  'REVENUE: % FEDERAL',
#  'TOTAL OTHER REVENUE(2020-21)',
#  'FUND BALANCE (FOR ISDS)',
#  'NET ASSETS (CHARTER SCHOOLS)',
#  'TOTAL ACTUAL EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
#  'EXPENDITURE: % INSTRUCTIONAL',
#  'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
#  'EXPENDITURE: % SCHOOL LEADERSHIP',
#  'EXPENDITURE: % PLANT SERVICES',
#  'EXPENDITURE: % OTHER OPERATING',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
#  ' EXPENDITURE: % BASIC EDUCATION SERVICES',
#  'EXPENDITURE: % SPECIAL EDUCATION',
#  'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
#  'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
#  'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
#  ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
#  'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
#  'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
#  'EXPENDITURE: % PREKINDERGARTEN',
#  'EXPENDITURE: % UN-ALLOCATED',
#  'DISTRICT SIZE',
#  'COMMUNITY TYPE',
#  'PROPERTY WEALTH',
#  'TAX RATE']

# %%
all_info = all_info.drop(columns=['DISTRICT NAME',
 'DISTRICT NUMBER',
 'COUNTY NUMBER AND NAME',
 'EDUCATION SERVICE CENTER REGION',
 'TOTAL NUMBER OF SCHOOLS',
 'STUDENTS: % AFRICAN AMERICAN',
 'STUDENTS: % HISPANIC',
 'STUDENTS: % WHITE',
 'STUDENTS: % AMERICAN INDIAN',
 'STUDENTS: % ASIAN',
 'STUDENTS: % PACIFIC ISLANDER',
 'STUDENTS: % TWO OR MORE RACES',
 'STUDENTS: % ECONOMICALLY DISADVANTAGED',
 'STUDENTS: % ENGLISH LEARNERS (EL)',
 'STUDENTS: % SPECIAL EDUCATION',
 'STUDENTS: % BILINGUAL/ESL EDUCATION',
 'STUDENTS: % CAREER & TECHNICAL EDUCATION',
 'STUDENTS: % GIFTED & TALENTED EDUCATION',
 '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
 ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
 'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
 'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
 'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
 'SAT-AVERAGE SCORE (2021-2020)',
 'ACT-AVERAGE SCORE (2021-2020)',
 'TOTAL STAFF FTE',
 'TOTAL TEACHER FTE',
 'STAFF: % CENTRAL ADMINISTRATIVE',
 'STAFF: % SCHOOL ADMINISTRATIVE',
 'STAFF: % PROFESSIONAL SUPPORT',
 'STAFF: % TEACHERS',
 'STAFF: % EDUCATIONAL AIDES',
 'STAFF: % AUXILIARY',
 'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
 'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
 'AVERAGE SALARY: PROFESSIONAL SUPPORT',
 'AVERAGE SALARY: TEACHER',
 'STAFF: % MINORITY',
 'NUMBER OF STUDENTS PER TOTAL STAFF',
 'NUMBER OF STUDENTS PER TEACHER',
 'TEACHER: % WITH ADVANCED DEGREES',
 'TEACHER: TURNOVER RATE',
 'TEACHER: % AFRICAN AMERICAN',
 'TEACHER: % HISPANIC',
 'TEACHER: % WHITE',
 'TEACHER: % AMERICAN INDIAN',
 'TEACHER: % ASIAN',
 'TEACHER: % PACIFIC ISLANDER',
 'TEACHER: % TWO OR MORE RACES',
 'TEACHER: % REGULAR EDUCATION',
 'TEACHER: % SPECIAL EDUCATION',
 'TEACHER: % COMPENSATORY EDUCATION',
 'TEACHER: % BILINGUAL/ESL EDUCATION',
 'TEACHER: % CAREER & TECHNICAL EDUCATION',
 'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
 'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
 'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
 'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
 'Total OPERATING AND OTHER REVENUE PER PUPIL',
 'Total OPERATING REVENUE (2020-21)',
 'REVENUE: % STATE',
 'REVENUE: % LOCAL AND OTHER',
 'REVENUE: % FEDERAL',
 'TOTAL OTHER REVENUE(2020-21)',
 'FUND BALANCE (FOR ISDS)',
 'NET ASSETS (CHARTER SCHOOLS)',
 'TOTAL ACTUAL EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
 'EXPENDITURE: % INSTRUCTIONAL',
 'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
 'EXPENDITURE: % SCHOOL LEADERSHIP',
 'EXPENDITURE: % PLANT SERVICES',
 'EXPENDITURE: % OTHER OPERATING',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
 ' EXPENDITURE: % BASIC EDUCATION SERVICES',
 'EXPENDITURE: % SPECIAL EDUCATION',
 'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
 'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
 'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
 ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
 'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
 'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
 'EXPENDITURE: % PREKINDERGARTEN',
 'EXPENDITURE: % UN-ALLOCATED',
 'DISTRICT SIZE',
 'PROPERTY WEALTH',
 'TAX RATE'])

# %%
all_info.columns.to_list()
# Out:
# ['DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL STUDENTS',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'COMMUNITY TYPE']

# %%
all_info = pd.get_dummies(all_info, columns=['TOTAL STUDENTS',
 'ATTENDANCE RATE (2020-21)',
 'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
 '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
 'ANNUAL GRADUATE COUNT (2020-21)',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
 'TEACHER: AVERAGE YEARS OF EXPERIENCE',
 'COMMUNITY TYPE'])

# %%
all_info=all_info.dropna()

# %%
# Remove 'DISTRICT ACCOUNTABILITY RATINGS' target from features data
X = all_info.drop(columns=['DISTRICT ACCOUNTABILITY RATINGS']) 
y = all_info['DISTRICT ACCOUNTABILITY RATINGS']  

# Split the data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variables
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (905, 2663)

# %%
# Define the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=2663))
# Add more hidden layers
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=50, activation='relu'))
model.add(tf.keras.layers.Dense(units=10, activation='relu'))

# Add the output layer
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                │ (None, 80)             │       213,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 100)            │         8,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │           510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 226,791 (885.90 KB)
#  Trainable params: 226,791 (885.90 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train_scaled, y_train_encoded, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3438 - loss: 1.5532 - val_accuracy: 0.4862 - val_loss: 0.7743
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6175 - loss: 1.3006 - val_accuracy: 0.5249 - val_loss: 0.7684
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6026 - loss: 1.1090 - val_accuracy: 0.5304 - val_loss: 0.7071
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5461 - loss: 1.0690 - val_accuracy: 0.5359 - val_loss: 0.6377
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7738 - loss: 0.9619 - val_accuracy: 0.6740 - val_loss: 0.5739
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8439 - loss: 0.8853 - val_accuracy: 0.6796 - val_loss: 0.5659
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8379 - loss: 0.8002 - val_accuracy: 0.6851 - val_loss: 0.5706
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.7775 - val_accuracy: 0.6851 - val_loss: 0.5720
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.8487 - val_accuracy: 0.6740 - val_loss: 0.5726
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8859 - loss: 0.6985 - val_accuracy: 0.6740 - val_loss: 0.5732
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8675 - loss: 0.7125 - val_accuracy: 0.6740 - val_loss: 0.5736
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.5174 - val_accuracy: 0.6685 - val_loss: 0.5742
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8549 - loss: 0.6659 - val_accuracy: 0.6740 - val_loss: 0.5746
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8621 - loss: 0.7399 - val_accuracy: 0.6740 - val_loss: 0.5751
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8669 - loss: 0.6270 - val_accuracy: 0.6740 - val_loss: 0.5755
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8552 - loss: 0.8020 - val_accuracy: 0.6740 - val_loss: 0.5759
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.7603 - val_accuracy: 0.6740 - val_loss: 0.5764
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8540 - loss: 0.7189 - val_accuracy: 0.6740 - val_loss: 0.5767
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8664 - loss: 0.7738 - val_accuracy: 0.6740 - val_loss: 0.5771
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.7333 - val_accuracy: 0.6740 - val_loss: 0.5775
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8521 - loss: 0.9467 - val_accuracy: 0.6740 - val_loss: 0.5778
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8361 - loss: 0.8574 - val_accuracy: 0.6740 - val_loss: 0.5781
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8630 - loss: 0.6501 - val_accuracy: 0.6740 - val_loss: 0.5785
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8436 - loss: 0.8331 - val_accuracy: 0.6740 - val_loss: 0.5787
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8689 - loss: 0.6023 - val_accuracy: 0.6740 - val_loss: 0.5790
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8632 - loss: 0.7705 - val_accuracy: 0.6740 - val_loss: 0.5793
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.6998 - val_accuracy: 0.6740 - val_loss: 0.5796
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.7856 - val_accuracy: 0.6740 - val_loss: 0.5799
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8299 - loss: 0.8984 - val_accuracy: 0.6740 - val_loss: 0.5801
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8306 - loss: 0.9607 - val_accuracy: 0.6740 - val_loss: 0.5804
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8858 - loss: 0.7328 - val_accuracy: 0.6740 - val_loss: 0.5806
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8237 - loss: 0.8567 - val_accuracy: 0.6740 - val_loss: 0.5808
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.6471 - val_accuracy: 0.6740 - val_loss: 0.5811
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8360 - loss: 0.7996 - val_accuracy: 0.6740 - val_loss: 0.5813
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.8356 - val_accuracy: 0.6740 - val_loss: 0.5815
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8362 - loss: 0.7480 - val_accuracy: 0.6796 - val_loss: 0.5817
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8374 - loss: 0.8627 - val_accuracy: 0.6796 - val_loss: 0.5819
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.7963 - val_accuracy: 0.6796 - val_loss: 0.5821
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8596 - loss: 0.6954 - val_accuracy: 0.6796 - val_loss: 0.5823
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 0.9625 - val_accuracy: 0.6796 - val_loss: 0.5825
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8517 - loss: 0.8861 - val_accuracy: 0.6796 - val_loss: 0.5827
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8605 - loss: 0.6991 - val_accuracy: 0.6796 - val_loss: 0.5829
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.9687 - val_accuracy: 0.6796 - val_loss: 0.5831
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8587 - loss: 0.6826 - val_accuracy: 0.6796 - val_loss: 0.5833
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.7737 - val_accuracy: 0.6796 - val_loss: 0.5835
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8349 - loss: 1.0811 - val_accuracy: 0.6796 - val_loss: 0.5837
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8321 - loss: 0.8824 - val_accuracy: 0.6796 - val_loss: 0.5839
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.7764 - val_accuracy: 0.6796 - val_loss: 0.5841
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8419 - loss: 0.8220 - val_accuracy: 0.6796 - val_loss: 0.5842
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8680 - loss: 0.7388 - val_accuracy: 0.6796 - val_loss: 0.5844
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8529 - loss: 0.7914 - val_accuracy: 0.6796 - val_loss: 0.5846
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 1.0892 - val_accuracy: 0.6796 - val_loss: 0.5847
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8539 - loss: 0.6685 - val_accuracy: 0.6796 - val_loss: 0.5849
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8432 - loss: 0.8921 - val_accuracy: 0.6796 - val_loss: 0.5850
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8445 - loss: 0.9235 - val_accuracy: 0.6796 - val_loss: 0.5852
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8604 - loss: 0.7875 - val_accuracy: 0.6740 - val_loss: 0.5853
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 1.0894 - val_accuracy: 0.6740 - val_loss: 0.5854
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8587 - loss: 0.6685 - val_accuracy: 0.6740 - val_loss: 0.5856
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8629 - loss: 0.7600 - val_accuracy: 0.6740 - val_loss: 0.5857
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8545 - loss: 0.8112 - val_accuracy: 0.6740 - val_loss: 0.5858
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8544 - loss: 0.7226 - val_accuracy: 0.6740 - val_loss: 0.5859
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8568 - loss: 0.8237 - val_accuracy: 0.6740 - val_loss: 0.5860
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8520 - loss: 0.7067 - val_accuracy: 0.6740 - val_loss: 0.5862
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8453 - loss: 0.8478 - val_accuracy: 0.6740 - val_loss: 0.5863
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8632 - loss: 0.6881 - val_accuracy: 0.6740 - val_loss: 0.5864
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.8030 - val_accuracy: 0.6740 - val_loss: 0.5865
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8353 - loss: 0.7035 - val_accuracy: 0.6740 - val_loss: 0.5866
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8477 - loss: 0.8296 - val_accuracy: 0.6740 - val_loss: 0.5868
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8796 - loss: 0.5355 - val_accuracy: 0.6740 - val_loss: 0.5869
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8543 - loss: 0.8003 - val_accuracy: 0.6740 - val_loss: 0.5870
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8634 - loss: 0.6716 - val_accuracy: 0.6740 - val_loss: 0.5871
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8556 - loss: 0.7252 - val_accuracy: 0.6740 - val_loss: 0.5872
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8513 - loss: 0.7838 - val_accuracy: 0.6740 - val_loss: 0.5873
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8669 - loss: 0.5905 - val_accuracy: 0.6740 - val_loss: 0.5874
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8538 - loss: 0.7411 - val_accuracy: 0.6740 - val_loss: 0.5876
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8265 - loss: 0.8893 - val_accuracy: 0.6740 - val_loss: 0.5877
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.6985 - val_accuracy: 0.6740 - val_loss: 0.5878
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8646 - loss: 0.6878 - val_accuracy: 0.6740 - val_loss: 0.5879
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8531 - loss: 0.6950 - val_accuracy: 0.6740 - val_loss: 0.5880
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8495 - loss: 0.7059 - val_accuracy: 0.6740 - val_loss: 0.5881
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8721 - loss: 0.6590 - val_accuracy: 0.6685 - val_loss: 0.5882
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8505 - loss: 0.8346 - val_accuracy: 0.6630 - val_loss: 0.5883
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8591 - loss: 0.7152 - val_accuracy: 0.6630 - val_loss: 0.5884
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.6572 - val_accuracy: 0.6630 - val_loss: 0.5885
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8668 - loss: 0.7883 - val_accuracy: 0.6630 - val_loss: 0.5886
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8592 - loss: 0.8193 - val_accuracy: 0.6630 - val_loss: 0.5887
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8567 - loss: 0.7300 - val_accuracy: 0.6630 - val_loss: 0.5887
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8451 - loss: 0.6807 - val_accuracy: 0.6630 - val_loss: 0.5888
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 1.0415 - val_accuracy: 0.6630 - val_loss: 0.5889
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.7669 - val_accuracy: 0.6630 - val_loss: 0.5890
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8582 - loss: 0.7624 - val_accuracy: 0.6630 - val_loss: 0.5891
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8452 - loss: 0.7772 - val_accuracy: 0.6630 - val_loss: 0.5892
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.9247 - val_accuracy: 0.6630 - val_loss: 0.5893
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8413 - loss: 0.8378 - val_accuracy: 0.6630 - val_loss: 0.5894
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.8083 - val_accuracy: 0.6630 - val_loss: 0.5895
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8668 - loss: 0.5463 - val_accuracy: 0.6630 - val_loss: 0.5896
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.7207 - val_accuracy: 0.6630 - val_loss: 0.5896
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8446 - loss: 0.8198 - val_accuracy: 0.6630 - val_loss: 0.5897
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.6344 - val_accuracy: 0.6630 - val_loss: 0.5898
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8468 - loss: 0.7809 - val_accuracy: 0.6630 - val_loss: 0.5899

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10/10 - 0s - 2ms/step - accuracy: 0.6225 - loss: 0.8838
# Loss: 0.8838368654251099, Accuracy: 0.6225165724754333
