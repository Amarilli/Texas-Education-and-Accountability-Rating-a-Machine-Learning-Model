# %%
import pandas as pd
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# %%
districts = pd.read_csv('Resources/tor20.21.csv')
staar = pd.read_csv('Resources/staar20_21.csv')
teacher = pd.read_csv('Resources/teachers20.21.csv')
all_info = pd.read_csv('Resources/DISTRICTS_INFO_2020.21.csv')

# %%
all_info.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'DISTRICT NUMBER',
#  'COUNTY NUMBER AND NAME',
#  'EDUCATION SERVICE CENTER REGION',
#  'DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL NUMBER OF SCHOOLS',
#  'TOTAL STUDENTS',
#  'STUDENTS: % AFRICAN AMERICAN',
#  'STUDENTS: % HISPANIC',
#  'STUDENTS: % WHITE',
#  'STUDENTS: % AMERICAN INDIAN',
#  'STUDENTS: % ASIAN',
#  'STUDENTS: % PACIFIC ISLANDER',
#  'STUDENTS: % TWO OR MORE RACES',
#  'STUDENTS: % ECONOMICALLY DISADVANTAGED',
#  'STUDENTS: % ENGLISH LEARNERS (EL)',
#  'STUDENTS: % SPECIAL EDUCATION',
#  'STUDENTS: % BILINGUAL/ESL EDUCATION',
#  'STUDENTS: % CAREER & TECHNICAL EDUCATION',
#  'STUDENTS: % GIFTED & TALENTED EDUCATION',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
#  ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
#  'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
#  'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
#  'SAT-AVERAGE SCORE (2021-2020)',
#  'ACT-AVERAGE SCORE (2021-2020)',
#  'TOTAL STAFF FTE',
#  'TOTAL TEACHER FTE',
#  'STAFF: % CENTRAL ADMINISTRATIVE',
#  'STAFF: % SCHOOL ADMINISTRATIVE',
#  'STAFF: % PROFESSIONAL SUPPORT',
#  'STAFF: % TEACHERS',
#  'STAFF: % EDUCATIONAL AIDES',
#  'STAFF: % AUXILIARY',
#  'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
#  'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
#  'AVERAGE SALARY: PROFESSIONAL SUPPORT',
#  'AVERAGE SALARY: TEACHER',
#  'STAFF: % MINORITY',
#  'NUMBER OF STUDENTS PER TOTAL STAFF',
#  'NUMBER OF STUDENTS PER TEACHER',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'TEACHER: % WITH ADVANCED DEGREES',
#  'TEACHER: TURNOVER RATE',
#  'TEACHER: % AFRICAN AMERICAN',
#  'TEACHER: % HISPANIC',
#  'TEACHER: % WHITE',
#  'TEACHER: % AMERICAN INDIAN',
#  'TEACHER: % ASIAN',
#  'TEACHER: % PACIFIC ISLANDER',
#  'TEACHER: % TWO OR MORE RACES',
#  'TEACHER: % REGULAR EDUCATION',
#  'TEACHER: % SPECIAL EDUCATION',
#  'TEACHER: % COMPENSATORY EDUCATION',
#  'TEACHER: % BILINGUAL/ESL EDUCATION',
#  'TEACHER: % CAREER & TECHNICAL EDUCATION',
#  'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
#  'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
#  'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
#  'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
#  'Total OPERATING AND OTHER REVENUE PER PUPIL',
#  'Total OPERATING REVENUE (2020-21)',
#  'REVENUE: % STATE',
#  'REVENUE: % LOCAL AND OTHER',
#  'REVENUE: % FEDERAL',
#  'TOTAL OTHER REVENUE(2020-21)',
#  'FUND BALANCE (FOR ISDS)',
#  'NET ASSETS (CHARTER SCHOOLS)',
#  'TOTAL ACTUAL EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
#  'EXPENDITURE: % INSTRUCTIONAL',
#  'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
#  'EXPENDITURE: % SCHOOL LEADERSHIP',
#  'EXPENDITURE: % PLANT SERVICES',
#  'EXPENDITURE: % OTHER OPERATING',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
#  ' EXPENDITURE: % BASIC EDUCATION SERVICES',
#  'EXPENDITURE: % SPECIAL EDUCATION',
#  'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
#  'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
#  'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
#  ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
#  'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
#  'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
#  'EXPENDITURE: % PREKINDERGARTEN',
#  'EXPENDITURE: % UN-ALLOCATED',
#  'DISTRICT SIZE',
#  'COMMUNITY TYPE',
#  'PROPERTY WEALTH',
#  'TAX RATE']

# %%
all_info = all_info.drop(columns=['DISTRICT NUMBER',
 'COUNTY NUMBER AND NAME',
 'EDUCATION SERVICE CENTER REGION','ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)'],)

# %%
all_info.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL NUMBER OF SCHOOLS',
#  'TOTAL STUDENTS',
#  'STUDENTS: % AFRICAN AMERICAN',
#  'STUDENTS: % HISPANIC',
#  'STUDENTS: % WHITE',
#  'STUDENTS: % AMERICAN INDIAN',
#  'STUDENTS: % ASIAN',
#  'STUDENTS: % PACIFIC ISLANDER',
#  'STUDENTS: % TWO OR MORE RACES',
#  'STUDENTS: % ECONOMICALLY DISADVANTAGED',
#  'STUDENTS: % ENGLISH LEARNERS (EL)',
#  'STUDENTS: % SPECIAL EDUCATION',
#  'STUDENTS: % BILINGUAL/ESL EDUCATION',
#  'STUDENTS: % CAREER & TECHNICAL EDUCATION',
#  'STUDENTS: % GIFTED & TALENTED EDUCATION',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
#  ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
#  'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
#  'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
#  'SAT-AVERAGE SCORE (2021-2020)',
#  'ACT-AVERAGE SCORE (2021-2020)',
#  'TOTAL STAFF FTE',
#  'TOTAL TEACHER FTE',
#  'STAFF: % CENTRAL ADMINISTRATIVE',
#  'STAFF: % SCHOOL ADMINISTRATIVE',
#  'STAFF: % PROFESSIONAL SUPPORT',
#  'STAFF: % TEACHERS',
#  'STAFF: % EDUCATIONAL AIDES',
#  'STAFF: % AUXILIARY',
#  'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
#  'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
#  'AVERAGE SALARY: PROFESSIONAL SUPPORT',
#  'AVERAGE SALARY: TEACHER',
#  'STAFF: % MINORITY',
#  'NUMBER OF STUDENTS PER TOTAL STAFF',
#  'NUMBER OF STUDENTS PER TEACHER',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'TEACHER: % WITH ADVANCED DEGREES',
#  'TEACHER: TURNOVER RATE',
#  'TEACHER: % AFRICAN AMERICAN',
#  'TEACHER: % HISPANIC',
#  'TEACHER: % WHITE',
#  'TEACHER: % AMERICAN INDIAN',
#  'TEACHER: % ASIAN',
#  'TEACHER: % PACIFIC ISLANDER',
#  'TEACHER: % TWO OR MORE RACES',
#  'TEACHER: % REGULAR EDUCATION',
#  'TEACHER: % SPECIAL EDUCATION',
#  'TEACHER: % COMPENSATORY EDUCATION',
#  'TEACHER: % BILINGUAL/ESL EDUCATION',
#  'TEACHER: % CAREER & TECHNICAL EDUCATION',
#  'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
#  'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
#  'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
#  'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
#  'Total OPERATING AND OTHER REVENUE PER PUPIL',
#  'Total OPERATING REVENUE (2020-21)',
#  'REVENUE: % STATE',
#  'REVENUE: % LOCAL AND OTHER',
#  'REVENUE: % FEDERAL',
#  'TOTAL OTHER REVENUE(2020-21)',
#  'FUND BALANCE (FOR ISDS)',
#  'NET ASSETS (CHARTER SCHOOLS)',
#  'TOTAL ACTUAL EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
#  'EXPENDITURE: % INSTRUCTIONAL',
#  'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
#  'EXPENDITURE: % SCHOOL LEADERSHIP',
#  'EXPENDITURE: % PLANT SERVICES',
#  'EXPENDITURE: % OTHER OPERATING',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
#  ' EXPENDITURE: % BASIC EDUCATION SERVICES',
#  'EXPENDITURE: % SPECIAL EDUCATION',
#  'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
#  'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
#  'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
#  ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
#  'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
#  'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
#  'EXPENDITURE: % PREKINDERGARTEN',
#  'EXPENDITURE: % UN-ALLOCATED',
#  'DISTRICT SIZE',
#  'COMMUNITY TYPE',
#  'PROPERTY WEALTH',
#  'TAX RATE']

# %%
all_info = pd.get_dummies(all_info, columns=['DISTRICT NAME',
 'TOTAL NUMBER OF SCHOOLS',
 'TOTAL STUDENTS',
 'STUDENTS: % AFRICAN AMERICAN',
 'STUDENTS: % HISPANIC',
 'STUDENTS: % WHITE',
 'STUDENTS: % AMERICAN INDIAN',
 'STUDENTS: % ASIAN',
 'STUDENTS: % PACIFIC ISLANDER',
 'STUDENTS: % TWO OR MORE RACES',
 'STUDENTS: % ECONOMICALLY DISADVANTAGED',
 'STUDENTS: % ENGLISH LEARNERS (EL)',
 'STUDENTS: % SPECIAL EDUCATION',
 'STUDENTS: % BILINGUAL/ESL EDUCATION',
 'STUDENTS: % CAREER & TECHNICAL EDUCATION',
 'STUDENTS: % GIFTED & TALENTED EDUCATION',
 'ATTENDANCE RATE (2020-21)',
 'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
 '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
 '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
 ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
 'ANNUAL GRADUATE COUNT (2020-21)',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
 'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
 'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
 'SAT-AVERAGE SCORE (2021-2020)',
 'ACT-AVERAGE SCORE (2021-2020)',
 'TOTAL STAFF FTE',
 'TOTAL TEACHER FTE',
 'STAFF: % CENTRAL ADMINISTRATIVE',
 'STAFF: % SCHOOL ADMINISTRATIVE',
 'STAFF: % PROFESSIONAL SUPPORT',
 'STAFF: % TEACHERS',
 'STAFF: % EDUCATIONAL AIDES',
 'STAFF: % AUXILIARY',
 'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
 'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
 'AVERAGE SALARY: PROFESSIONAL SUPPORT',
 'AVERAGE SALARY: TEACHER',
 'STAFF: % MINORITY',
 'NUMBER OF STUDENTS PER TOTAL STAFF',
 'NUMBER OF STUDENTS PER TEACHER',
 'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
 'TEACHER: AVERAGE YEARS OF EXPERIENCE',
 'TEACHER: % WITH ADVANCED DEGREES',
 'TEACHER: TURNOVER RATE',
 'TEACHER: % AFRICAN AMERICAN',
 'TEACHER: % HISPANIC',
 'TEACHER: % WHITE',
 'TEACHER: % AMERICAN INDIAN',
 'TEACHER: % ASIAN',
 'TEACHER: % PACIFIC ISLANDER',
 'TEACHER: % TWO OR MORE RACES',
 'TEACHER: % REGULAR EDUCATION',
 'TEACHER: % SPECIAL EDUCATION',
 'TEACHER: % COMPENSATORY EDUCATION',
 'TEACHER: % BILINGUAL/ESL EDUCATION',
 'TEACHER: % CAREER & TECHNICAL EDUCATION',
 'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
 'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
 'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
 'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
 'Total OPERATING AND OTHER REVENUE PER PUPIL',
 'Total OPERATING REVENUE (2020-21)',
 'REVENUE: % STATE',
 'REVENUE: % LOCAL AND OTHER',
 'REVENUE: % FEDERAL',
 'TOTAL OTHER REVENUE(2020-21)',
 'FUND BALANCE (FOR ISDS)',
 'NET ASSETS (CHARTER SCHOOLS)',
 'TOTAL ACTUAL EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
 'EXPENDITURE: % INSTRUCTIONAL',
 'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
 'EXPENDITURE: % SCHOOL LEADERSHIP',
 'EXPENDITURE: % PLANT SERVICES',
 'EXPENDITURE: % OTHER OPERATING',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
 ' EXPENDITURE: % BASIC EDUCATION SERVICES',
 'EXPENDITURE: % SPECIAL EDUCATION',
 'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
 'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
 'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
 ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
 'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
 'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
 'EXPENDITURE: % PREKINDERGARTEN',
 'EXPENDITURE: % UN-ALLOCATED',
 'DISTRICT SIZE',
 'COMMUNITY TYPE',
 'PROPERTY WEALTH',
 'TAX RATE'])

# %%
all_info=all_info.dropna()

# %%
# Remove 'DISTRICT ACCOUNTABILITY RATINGS' target from features data
X = all_info.drop(columns=['DISTRICT ACCOUNTABILITY RATINGS']) 
y = all_info['DISTRICT ACCOUNTABILITY RATINGS']  

# Split the data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variables
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (905, 40943)

# %%
# Define the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='linear')  # Output layer with linear activation for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])  # Mean squared error loss for regression

# Train the model
model.fit(X_train_scaled, y_train_encoded, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4253 - loss: 6.5847 - val_accuracy: 0.3867 - val_loss: 8.0640
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5095 - loss: 78.4927 - val_accuracy: 0.3702 - val_loss: 42.6789
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3842 - loss: 28.7585 - val_accuracy: 0.4033 - val_loss: 5.9229
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5012 - loss: 11.5543 - val_accuracy: 0.3646 - val_loss: 47.7231
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4975 - loss: 8.0980 - val_accuracy: 0.3591 - val_loss: 7.3441
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5487 - loss: 5.3927 - val_accuracy: 0.3646 - val_loss: 51.4707
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5077 - loss: 3.1031 - val_accuracy: 0.3646 - val_loss: 27.0928
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5822 - loss: 2.2697 - val_accuracy: 0.3646 - val_loss: 28.8779
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6318 - loss: 1.7846 - val_accuracy: 0.3646 - val_loss: 35.3462
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6437 - loss: 1.2305 - val_accuracy: 0.3646 - val_loss: 32.2189
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7181 - loss: 0.7580 - val_accuracy: 0.3646 - val_loss: 50.9293
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6818 - loss: 0.7541 - val_accuracy: 0.3646 - val_loss: 35.1020
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6791 - loss: 0.6304 - val_accuracy: 0.3646 - val_loss: 34.0132
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7451 - loss: 0.5215 - val_accuracy: 0.3646 - val_loss: 30.7121
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7234 - loss: 0.5100 - val_accuracy: 0.3646 - val_loss: 36.3844
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7318 - loss: 0.5367 - val_accuracy: 0.3646 - val_loss: 32.6301
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7173 - loss: 0.4986 - val_accuracy: 0.3646 - val_loss: 36.3807
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7566 - loss: 0.4498 - val_accuracy: 0.3646 - val_loss: 32.1059
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7270 - loss: 0.4774 - val_accuracy: 0.3646 - val_loss: 33.7952
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7358 - loss: 0.4875 - val_accuracy: 0.3646 - val_loss: 30.3709
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7581 - loss: 0.4472 - val_accuracy: 0.3646 - val_loss: 35.1855
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6968 - loss: 0.5422 - val_accuracy: 0.3646 - val_loss: 29.1593
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7198 - loss: 0.6210 - val_accuracy: 0.3646 - val_loss: 32.8255
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7190 - loss: 0.6919 - val_accuracy: 0.3646 - val_loss: 22.3727
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6817 - loss: 0.7811 - val_accuracy: 0.3646 - val_loss: 39.4189
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6868 - loss: 0.7574 - val_accuracy: 0.3646 - val_loss: 23.3259
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7150 - loss: 0.7184 - val_accuracy: 0.3646 - val_loss: 30.9417
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7135 - loss: 0.6081 - val_accuracy: 0.3646 - val_loss: 23.5816
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7316 - loss: 0.6546 - val_accuracy: 0.3646 - val_loss: 20.6066
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7100 - loss: 0.6215 - val_accuracy: 0.3646 - val_loss: 24.7344
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7351 - loss: 0.5010 - val_accuracy: 0.3646 - val_loss: 28.2756
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7393 - loss: 0.4287 - val_accuracy: 0.3702 - val_loss: 18.2265
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7442 - loss: 0.3335 - val_accuracy: 0.3646 - val_loss: 23.9401
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7557 - loss: 0.2684 - val_accuracy: 0.3646 - val_loss: 24.8232
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7653 - loss: 0.3039 - val_accuracy: 0.3646 - val_loss: 27.4884
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7548 - loss: 0.2180 - val_accuracy: 0.3646 - val_loss: 19.8911
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7820 - loss: 0.2300 - val_accuracy: 0.3646 - val_loss: 23.3483
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7780 - loss: 0.2164 - val_accuracy: 0.3646 - val_loss: 21.2795
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8059 - loss: 0.2158 - val_accuracy: 0.3646 - val_loss: 23.1733
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7966 - loss: 0.2127 - val_accuracy: 0.3646 - val_loss: 20.3351
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8044 - loss: 0.1575 - val_accuracy: 0.3646 - val_loss: 25.7184
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8139 - loss: 0.1723 - val_accuracy: 0.3646 - val_loss: 22.4121
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7782 - loss: 0.1903 - val_accuracy: 0.3646 - val_loss: 25.7787
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8137 - loss: 0.1948 - val_accuracy: 0.3646 - val_loss: 19.7868
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7805 - loss: 0.1802 - val_accuracy: 0.3646 - val_loss: 24.0037
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7503 - loss: 0.2875 - val_accuracy: 0.3646 - val_loss: 18.8535
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7840 - loss: 0.2480 - val_accuracy: 0.3646 - val_loss: 24.0562
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7644 - loss: 0.2387 - val_accuracy: 0.3646 - val_loss: 19.5845
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7535 - loss: 0.2544 - val_accuracy: 0.3646 - val_loss: 27.3688
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7914 - loss: 0.2900 - val_accuracy: 0.3757 - val_loss: 15.3620
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7653 - loss: 0.3011 - val_accuracy: 0.3646 - val_loss: 27.4037
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7422 - loss: 0.3989 - val_accuracy: 0.3757 - val_loss: 11.1794
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7608 - loss: 0.4207 - val_accuracy: 0.3646 - val_loss: 22.9927
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7342 - loss: 0.4550 - val_accuracy: 0.3867 - val_loss: 8.2782
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7369 - loss: 0.3786 - val_accuracy: 0.3646 - val_loss: 21.5523
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7457 - loss: 0.3894 - val_accuracy: 0.3812 - val_loss: 12.1903
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7666 - loss: 0.2993 - val_accuracy: 0.3646 - val_loss: 20.5253
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7638 - loss: 0.3526 - val_accuracy: 0.3757 - val_loss: 14.5456
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7340 - loss: 0.2973 - val_accuracy: 0.3646 - val_loss: 20.7864
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7404 - loss: 0.2942 - val_accuracy: 0.3646 - val_loss: 15.8157
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7704 - loss: 0.3107 - val_accuracy: 0.3646 - val_loss: 17.8997
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7849 - loss: 0.2820 - val_accuracy: 0.3812 - val_loss: 12.9868
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7793 - loss: 0.2608 - val_accuracy: 0.3646 - val_loss: 24.6810
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7632 - loss: 0.2564 - val_accuracy: 0.3646 - val_loss: 15.9667
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7599 - loss: 0.2321 - val_accuracy: 0.3646 - val_loss: 18.0899
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7781 - loss: 0.2417 - val_accuracy: 0.3812 - val_loss: 11.5416
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7705 - loss: 0.2608 - val_accuracy: 0.3757 - val_loss: 11.8311
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7558 - loss: 0.2062 - val_accuracy: 0.3702 - val_loss: 15.7986
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7948 - loss: 0.2071 - val_accuracy: 0.3757 - val_loss: 12.4070
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7619 - loss: 0.1722 - val_accuracy: 0.3757 - val_loss: 12.4416
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8310 - loss: 0.1406 - val_accuracy: 0.3702 - val_loss: 15.2279
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7646 - loss: 0.1383 - val_accuracy: 0.3646 - val_loss: 16.1678
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8293 - loss: 0.1047 - val_accuracy: 0.3757 - val_loss: 14.1423
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8391 - loss: 0.0651 - val_accuracy: 0.3646 - val_loss: 14.8142
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8379 - loss: 0.0648 - val_accuracy: 0.3757 - val_loss: 13.3252
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8405 - loss: 0.0601 - val_accuracy: 0.3757 - val_loss: 13.0356
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8472 - loss: 0.0447 - val_accuracy: 0.3757 - val_loss: 11.2244
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8387 - loss: 0.0499 - val_accuracy: 0.3646 - val_loss: 15.4680
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8436 - loss: 0.0452 - val_accuracy: 0.3812 - val_loss: 11.0094
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8389 - loss: 0.0521 - val_accuracy: 0.3757 - val_loss: 12.9264
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8435 - loss: 0.0458 - val_accuracy: 0.3757 - val_loss: 11.5639
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8379 - loss: 0.0480 - val_accuracy: 0.3757 - val_loss: 12.5513
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8434 - loss: 0.0663 - val_accuracy: 0.3757 - val_loss: 13.2645
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8159 - loss: 0.0668 - val_accuracy: 0.3702 - val_loss: 13.2759
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8329 - loss: 0.0862 - val_accuracy: 0.3757 - val_loss: 10.5502
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8232 - loss: 0.0856 - val_accuracy: 0.3646 - val_loss: 15.9607
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8156 - loss: 0.0888 - val_accuracy: 0.3757 - val_loss: 10.7369
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7931 - loss: 0.0950 - val_accuracy: 0.3702 - val_loss: 12.5323
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8179 - loss: 0.1124 - val_accuracy: 0.3812 - val_loss: 9.9865
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8099 - loss: 0.1745 - val_accuracy: 0.3757 - val_loss: 11.2383
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7988 - loss: 0.1856 - val_accuracy: 0.3757 - val_loss: 12.1776
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7847 - loss: 0.1460 - val_accuracy: 0.3646 - val_loss: 14.7774
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8056 - loss: 0.1730 - val_accuracy: 0.3702 - val_loss: 12.5592
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8074 - loss: 0.1672 - val_accuracy: 0.3646 - val_loss: 16.0620
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7726 - loss: 0.1922 - val_accuracy: 0.3702 - val_loss: 11.3293
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8099 - loss: 0.1721 - val_accuracy: 0.3646 - val_loss: 13.8041
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7807 - loss: 0.1940 - val_accuracy: 0.3757 - val_loss: 8.7644
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7658 - loss: 0.2496 - val_accuracy: 0.3646 - val_loss: 14.7778
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7594 - loss: 0.2067 - val_accuracy: 0.3646 - val_loss: 13.9228
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7725 - loss: 0.2170 - val_accuracy: 0.3646 - val_loss: 11.1116

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10/10 - 0s - 3ms/step - accuracy: 0.3311 - loss: 1.5761
# Loss: 1.576055645942688, Accuracy: 0.33112582564353943
