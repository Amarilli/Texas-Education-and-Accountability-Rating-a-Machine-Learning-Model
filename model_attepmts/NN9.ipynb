# %%
import pandas as pd
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
import keras_tuner as kt
from kerastuner.tuners import Hyperband
from kerastuner import HyperParameters
import matplotlib.pyplot as plt

# %%
districts = pd.read_csv('Resources/tor20.21.csv')
staar = pd.read_csv('Resources/staar20.21.cleaned.csv')
teacher = pd.read_csv('Resources/teachers_scores20_21.csv')
all_info = pd.read_csv('Resources/DISTRICTS_INFO_2020.21.csv')
staar19 = pd.read_csv('Resources/staar19_20.csv')
ratings = pd.read_csv('Resources/statewideoverallaccountabilityratings2022.csv')

# %%
completedf = pd.merge(staar19, all_info, on='DISTRICT NAME', how="inner")

# %%
completedf['Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'] - completedf[' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD']
completedf['Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf['Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y'] - completedf['STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x']
completedf['Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf['Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y'] - completedf['STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x']
completedf['Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  ' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % WRITING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WRITING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WRITING AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  'DISTRICT NUMBER',
#  'COUNTY NUMBER AND NAME',
#  'EDUCATION SERVICE CENTER REGION',
#  'DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL NUMBER OF SCHOOLS',
#  'TOTAL STUDENTS',
#  'STUDENTS: % AFRICAN AMERICAN',
#  'STUDENTS: % HISPANIC',
#  'STUDENTS: % WHITE',
#  'STUDENTS: % AMERICAN INDIAN',
#  'STUDENTS: % ASIAN',
#  'STUDENTS: % PACIFIC ISLANDER',
#  'STUDENTS: % TWO OR MORE RACES',
#  'STUDENTS: % ECONOMICALLY DISADVANTAGED',
#  'STUDENTS: % ENGLISH LEARNERS (EL)',
#  'STUDENTS: % SPECIAL EDUCATION',
#  'STUDENTS: % BILINGUAL/ESL EDUCATION',
#  'STUDENTS: % CAREER & TECHNICAL EDUCATION',
#  'STUDENTS: % GIFTED & TALENTED EDUCATION',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
#  ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
#  'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
#  'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
#  'SAT-AVERAGE SCORE (2021-2020)',
#  'ACT-AVERAGE SCORE (2021-2020)',
#  'TOTAL STAFF FTE',
#  'TOTAL TEACHER FTE',
#  'STAFF: % CENTRAL ADMINISTRATIVE',
#  'STAFF: % SCHOOL ADMINISTRATIVE',
#  'STAFF: % PROFESSIONAL SUPPORT',
#  'STAFF: % TEACHERS',
#  'STAFF: % EDUCATIONAL AIDES',
#  'STAFF: % AUXILIARY',
#  'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
#  'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
#  'AVERAGE SALARY: PROFESSIONAL SUPPORT',
#  'AVERAGE SALARY: TEACHER',
#  'STAFF: % MINORITY',
#  'NUMBER OF STUDENTS PER TOTAL STAFF',
#  'NUMBER OF STUDENTS PER TEACHER',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'TEACHER: % WITH ADVANCED DEGREES',
#  'TEACHER: TURNOVER RATE',
#  'TEACHER: % AFRICAN AMERICAN',
#  'TEACHER: % HISPANIC',
#  'TEACHER: % WHITE',
#  'TEACHER: % AMERICAN INDIAN',
#  'TEACHER: % ASIAN',
#  'TEACHER: % PACIFIC ISLANDER',
#  'TEACHER: % TWO OR MORE RACES',
#  'TEACHER: % REGULAR EDUCATION',
#  'TEACHER: % SPECIAL EDUCATION',
#  'TEACHER: % COMPENSATORY EDUCATION',
#  'TEACHER: % BILINGUAL/ESL EDUCATION',
#  'TEACHER: % CAREER & TECHNICAL EDUCATION',
#  'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
#  'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
#  'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
#  'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
#  'Total OPERATING AND OTHER REVENUE PER PUPIL',
#  'Total OPERATING REVENUE (2020-21)',
#  'REVENUE: % STATE',
#  'REVENUE: % LOCAL AND OTHER',
#  'REVENUE: % FEDERAL',
#  'TOTAL OTHER REVENUE(2020-21)',
#  'FUND BALANCE (FOR ISDS)',
#  'NET ASSETS (CHARTER SCHOOLS)',
#  'TOTAL ACTUAL EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
#  'EXPENDITURE: % INSTRUCTIONAL',
#  'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
#  'EXPENDITURE: % SCHOOL LEADERSHIP',
#  'EXPENDITURE: % PLANT SERVICES',
#  'EXPENDITURE: % OTHER OPERATING',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
#  ' EXPENDITURE: % BASIC EDUCATION SERVICES',
#  'EXPENDITURE: % SPECIAL EDUCATION',
#  'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
#  'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
#  'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
#  ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
#  'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
#  'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
#  'EXPENDITURE: % PREKINDERGARTEN',
#  'EXPENDITURE: % UN-ALLOCATED',
#  'DISTRICT SIZE',
#  'COMMUNITY TYPE',
#  'PROPERTY WEALTH',
#  'TAX RATE',
#  'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE']

# %%
completedf = completedf.drop(columns=['DISTRICT ACCOUNTABILITY RATINGS',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % WRITING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WRITING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WRITING AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 'DISTRICT NUMBER',
 'COUNTY NUMBER AND NAME',
 'EDUCATION SERVICE CENTER REGION',
 'TOTAL NUMBER OF SCHOOLS',
 'STUDENTS: % AFRICAN AMERICAN',
 'STUDENTS: % HISPANIC',
 'STUDENTS: % WHITE',
 'STUDENTS: % AMERICAN INDIAN',
 'STUDENTS: % ASIAN',
 'STUDENTS: % PACIFIC ISLANDER',
 'STUDENTS: % TWO OR MORE RACES',
 'STUDENTS: % ECONOMICALLY DISADVANTAGED',
 'STUDENTS: % ENGLISH LEARNERS (EL)',
 'STUDENTS: % SPECIAL EDUCATION',
 'STUDENTS: % BILINGUAL/ESL EDUCATION',
 'STUDENTS: % CAREER & TECHNICAL EDUCATION',
 'STUDENTS: % GIFTED & TALENTED EDUCATION',
 'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
 '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
 ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
 'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_y',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
 'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
 'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
 'SAT-AVERAGE SCORE (2021-2020)',
 'ACT-AVERAGE SCORE (2021-2020)',
 'TOTAL STAFF FTE',
 'TOTAL TEACHER FTE',
 'STAFF: % CENTRAL ADMINISTRATIVE',
 'STAFF: % SCHOOL ADMINISTRATIVE',
 'STAFF: % PROFESSIONAL SUPPORT',
 'STAFF: % TEACHERS',
 'STAFF: % EDUCATIONAL AIDES',
 'STAFF: % AUXILIARY',
 'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
 'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
 'AVERAGE SALARY: PROFESSIONAL SUPPORT',
 'AVERAGE SALARY: TEACHER',
 'STAFF: % MINORITY',
 'NUMBER OF STUDENTS PER TOTAL STAFF',
 'NUMBER OF STUDENTS PER TEACHER',
 'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
 'TEACHER: % WITH ADVANCED DEGREES',
 'TEACHER: TURNOVER RATE',
 'TEACHER: % AFRICAN AMERICAN',
 'TEACHER: % HISPANIC',
 'TEACHER: % WHITE',
 'TEACHER: % AMERICAN INDIAN',
 'TEACHER: % ASIAN',
 'TEACHER: % PACIFIC ISLANDER',
 'TEACHER: % TWO OR MORE RACES',
 'TEACHER: % REGULAR EDUCATION',
 'TEACHER: % SPECIAL EDUCATION',
 'TEACHER: % COMPENSATORY EDUCATION',
 'TEACHER: % BILINGUAL/ESL EDUCATION',
 'TEACHER: % CAREER & TECHNICAL EDUCATION',
 'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
 'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
 'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
 'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
 'Total OPERATING AND OTHER REVENUE PER PUPIL',
 'Total OPERATING REVENUE (2020-21)',
 'REVENUE: % STATE',
 'REVENUE: % LOCAL AND OTHER',
 'REVENUE: % FEDERAL',
 'TOTAL OTHER REVENUE(2020-21)',
 'FUND BALANCE (FOR ISDS)',
 'NET ASSETS (CHARTER SCHOOLS)',
 'TOTAL ACTUAL EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
 'EXPENDITURE: % INSTRUCTIONAL',
 'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
 'EXPENDITURE: % SCHOOL LEADERSHIP',
 'EXPENDITURE: % PLANT SERVICES',
 'EXPENDITURE: % OTHER OPERATING',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
 ' EXPENDITURE: % BASIC EDUCATION SERVICES',
 'EXPENDITURE: % SPECIAL EDUCATION',
 'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
 'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
 'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
 ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
 'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
 'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
 'EXPENDITURE: % PREKINDERGARTEN',
 'EXPENDITURE: % UN-ALLOCATED',
 'DISTRICT SIZE',
 'PROPERTY WEALTH',
 'TAX RATE',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 ' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'])

# %%
ratings = ratings.rename(columns={'District': 'DISTRICT NAME'})

# %%
completedf = pd.merge(completedf, ratings, on='DISTRICT NAME', how="inner")

# %%
completedf.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'TOTAL STUDENTS',
#  'ATTENDANCE RATE (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'COMMUNITY TYPE',
#  'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'District\nNumber',
#  'Campus\nNumber',
#  'Campus',
#  'Region',
#  'County',
#  'School\nType',
#  'Grades\nServed',
#  'Alternative\nEducation\nAccountability',
#  'Charter',
#  'Number of\nStudents',
#  '%\nEconomically\nDisadvantaged',
#  '% EB/EL\nStudents',
#  'Overall\nRating',
#  'Overall\nScore',
#  'Student\nAchievement\nRating',
#  'Student\nAchievement\nScore',
#  'School\nProgress\nRating',
#  'School\nProgress\nScore',
#  'Academic\nGrowth\nRating',
#  'Academic\nGrowth\nScore',
#  'Relative\nPerformance\nRating',
#  'Relative\nPerformance\nScore',
#  'Closing\nthe Gaps Rating',
#  'Closing\nthe Gaps Score',
#  'Support\nLabel',
#  'Public\nEducation\nGrant',
#  'Distinction\nELA/Reading',
#  'Distinction\nMathematics',
#  'Distinction\nScience',
#  'Distinction\nSoc Studies',
#  'Distinction\nProgress',
#  'Distinction\nClosing the Gaps',
#  'Distinction\nPostsecondary\nReadiness',
#  'US Congress\nDistrict',
#  'US Congress\nElection District',
#  'TX House\nDistrict',
#  'TX House\nElection District',
#  'TX Senate\nDistrict',
#  'TX Senate\nElection District',
#  'Campus Enrollment\nType']

# %%
completedf =completedf.drop(columns=['District\nNumber',
 'Campus\nNumber',
 'Campus',
 'Region',
 'County',
 'School\nType',
 'Grades\nServed',
 'Alternative\nEducation\nAccountability',
 'Charter',
 'Number of\nStudents',
 '%\nEconomically\nDisadvantaged',
 '% EB/EL\nStudents',
 'Student\nAchievement\nRating',
 'School\nProgress\nRating',
 'Academic\nGrowth\nRating',
 'Relative\nPerformance\nRating',
 'Closing\nthe Gaps Rating',
 'Support\nLabel',
 'Public\nEducation\nGrant',
 'Distinction\nELA/Reading',
 'Distinction\nMathematics',
 'Distinction\nScience',
 'Distinction\nSoc Studies',
 'Distinction\nProgress',
 'Distinction\nClosing the Gaps',
 'Distinction\nPostsecondary\nReadiness',
 'US Congress\nDistrict',
 'US Congress\nElection District',
 'TX House\nDistrict',
 'TX House\nElection District',
 'TX Senate\nDistrict',
 'TX Senate\nElection District',
 'Campus Enrollment\nType',
 'Student\nAchievement\nScore',
 'School\nProgress\nScore',
 'Academic\nGrowth\nScore',
 'Relative\nPerformance\nScore',
 'Closing\nthe Gaps Score'])

# %%
completedf.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'TOTAL STUDENTS',
#  'ATTENDANCE RATE (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'COMMUNITY TYPE',
#  'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Overall\nRating',
#  'Overall\nScore']

# %%
completedf = pd.get_dummies(completedf, columns=[
'DISTRICT NAME',
 'TOTAL STUDENTS',
 'ATTENDANCE RATE (2020-21)',
 '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
 'ANNUAL GRADUATE COUNT (2020-21)',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
 'TEACHER: AVERAGE YEARS OF EXPERIENCE',
 'COMMUNITY TYPE',
 'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'Overall\nScore'])

# %%
completedf = completedf.dropna()

# %%
# Remove 'DISTRICT ACCOUNTABILITY RATINGS' target from features data
X = completedf.drop(columns=['Overall\nRating']) 
y = completedf['Overall\nRating']  

# Split the data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variables
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (7975, 4096)

# %%
# Define the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=4096))
# Add more hidden layers
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=50, activation='relu'))
model.add(tf.keras.layers.Dense(units=10, activation='relu'))

# Add the output layer
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# c:\Users\riahk\anaconda3\envs\geoviews\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 80)             │       327,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │         8,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │           510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 341,431 (1.30 MB)
#  Trainable params: 341,431 (1.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train_scaled, y_train_encoded, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4471 - loss: 1.6380 - val_accuracy: 0.5172 - val_loss: 1.5524
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5449 - loss: 1.4566 - val_accuracy: 0.5755 - val_loss: 1.5039
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6113 - loss: 1.4388 - val_accuracy: 0.6107 - val_loss: 1.4675
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6384 - loss: 1.3409 - val_accuracy: 0.6270 - val_loss: 1.4414
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6599 - loss: 1.2763 - val_accuracy: 0.6382 - val_loss: 1.4287
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6708 - loss: 1.3261 - val_accuracy: 0.6433 - val_loss: 1.4280
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6630 - loss: 1.3094 - val_accuracy: 0.6552 - val_loss: 1.4173
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6818 - loss: 1.3213 - val_accuracy: 0.6558 - val_loss: 1.4133
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6775 - loss: 1.3488 - val_accuracy: 0.6558 - val_loss: 1.4087
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6760 - loss: 1.3309 - val_accuracy: 0.6608 - val_loss: 1.4029
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6840 - loss: 1.2961 - val_accuracy: 0.6564 - val_loss: 1.4049
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6878 - loss: 1.2168 - val_accuracy: 0.6564 - val_loss: 1.4047
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6928 - loss: 1.2830 - val_accuracy: 0.6552 - val_loss: 1.4061
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6863 - loss: 1.2262 - val_accuracy: 0.6539 - val_loss: 1.4088
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6864 - loss: 1.3555 - val_accuracy: 0.6589 - val_loss: 1.4063
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6867 - loss: 1.2889 - val_accuracy: 0.6677 - val_loss: 1.4120
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6816 - loss: 1.3711 - val_accuracy: 0.6602 - val_loss: 1.4037
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6861 - loss: 1.3229 - val_accuracy: 0.6583 - val_loss: 1.4077
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6907 - loss: 1.2701 - val_accuracy: 0.6646 - val_loss: 1.4045
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7014 - loss: 1.3108 - val_accuracy: 0.6759 - val_loss: 1.3896
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6953 - loss: 1.3136 - val_accuracy: 0.6765 - val_loss: 1.3963
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6931 - loss: 1.3194 - val_accuracy: 0.6796 - val_loss: 1.3941
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6985 - loss: 1.3096 - val_accuracy: 0.6740 - val_loss: 1.3971
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6876 - loss: 1.2897 - val_accuracy: 0.6765 - val_loss: 1.3900
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6936 - loss: 1.2550 - val_accuracy: 0.6784 - val_loss: 1.3903
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6983 - loss: 1.3062 - val_accuracy: 0.6683 - val_loss: 1.3939
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6782 - loss: 1.2923 - val_accuracy: 0.6815 - val_loss: 1.3906
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6920 - loss: 1.3008 - val_accuracy: 0.6859 - val_loss: 1.3845
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7070 - loss: 1.2693 - val_accuracy: 0.6853 - val_loss: 1.3831
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6964 - loss: 1.2359 - val_accuracy: 0.6871 - val_loss: 1.3814
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7020 - loss: 1.2540 - val_accuracy: 0.6884 - val_loss: 1.3804
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6953 - loss: 1.3222 - val_accuracy: 0.6878 - val_loss: 1.3802
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6932 - loss: 1.2843 - val_accuracy: 0.6884 - val_loss: 1.3802
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6957 - loss: 1.3349 - val_accuracy: 0.6884 - val_loss: 1.3801
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6932 - loss: 1.2859 - val_accuracy: 0.6878 - val_loss: 1.3805
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6905 - loss: 1.3276 - val_accuracy: 0.6865 - val_loss: 1.3809
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7021 - loss: 1.2033 - val_accuracy: 0.6865 - val_loss: 1.3808
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6945 - loss: 1.2224 - val_accuracy: 0.6871 - val_loss: 1.3808
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6839 - loss: 1.3118 - val_accuracy: 0.6871 - val_loss: 1.3808
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6890 - loss: 1.3119 - val_accuracy: 0.6871 - val_loss: 1.3808
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6956 - loss: 1.2529 - val_accuracy: 0.6890 - val_loss: 1.3810
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6949 - loss: 1.2629 - val_accuracy: 0.6846 - val_loss: 1.3874
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6907 - loss: 1.2242 - val_accuracy: 0.6846 - val_loss: 1.3902
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7106 - loss: 1.2316 - val_accuracy: 0.6871 - val_loss: 1.3905
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6984 - loss: 1.3630 - val_accuracy: 0.6828 - val_loss: 1.3932
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6797 - loss: 1.3415 - val_accuracy: 0.6840 - val_loss: 1.3975
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6867 - loss: 1.2885 - val_accuracy: 0.6840 - val_loss: 1.3968
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6801 - loss: 1.3615 - val_accuracy: 0.6840 - val_loss: 1.3976
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6885 - loss: 1.2753 - val_accuracy: 0.6821 - val_loss: 1.3987
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6870 - loss: 1.3444 - val_accuracy: 0.6834 - val_loss: 1.3926
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6901 - loss: 1.3011 - val_accuracy: 0.6834 - val_loss: 1.3926
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6991 - loss: 1.2934 - val_accuracy: 0.6828 - val_loss: 1.3892
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6935 - loss: 1.2759 - val_accuracy: 0.6828 - val_loss: 1.3892
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6950 - loss: 1.2956 - val_accuracy: 0.6828 - val_loss: 1.3892
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6864 - loss: 1.3684 - val_accuracy: 0.6828 - val_loss: 1.3892
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6872 - loss: 1.3432 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6941 - loss: 1.3034 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6902 - loss: 1.2897 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6991 - loss: 1.3058 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6987 - loss: 1.2667 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6889 - loss: 1.3066 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6857 - loss: 1.3538 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6844 - loss: 1.3305 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6856 - loss: 1.3777 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6919 - loss: 1.3317 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6926 - loss: 1.3184 - val_accuracy: 0.6828 - val_loss: 1.3894
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7051 - loss: 1.3226 - val_accuracy: 0.6828 - val_loss: 1.3892
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6953 - loss: 1.2608 - val_accuracy: 0.6734 - val_loss: 1.3952
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6892 - loss: 1.3472 - val_accuracy: 0.6897 - val_loss: 1.3842
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6906 - loss: 1.3152 - val_accuracy: 0.6859 - val_loss: 1.3834
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6910 - loss: 1.3824 - val_accuracy: 0.6853 - val_loss: 1.3838
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6845 - loss: 1.2976 - val_accuracy: 0.6915 - val_loss: 1.3780
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6987 - loss: 1.2641 - val_accuracy: 0.6915 - val_loss: 1.3778
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6961 - loss: 1.2350 - val_accuracy: 0.6909 - val_loss: 1.3777
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6928 - loss: 1.3425 - val_accuracy: 0.6909 - val_loss: 1.3777
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6962 - loss: 1.2911 - val_accuracy: 0.6909 - val_loss: 1.3777
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6893 - loss: 1.3878 - val_accuracy: 0.6909 - val_loss: 1.3777
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6918 - loss: 1.2600 - val_accuracy: 0.6915 - val_loss: 1.3777
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6975 - loss: 1.3333 - val_accuracy: 0.6928 - val_loss: 1.3768
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6839 - loss: 1.3251 - val_accuracy: 0.6922 - val_loss: 1.3772
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6912 - loss: 1.2844 - val_accuracy: 0.6915 - val_loss: 1.3783
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6982 - loss: 1.2669 - val_accuracy: 0.6915 - val_loss: 1.3772
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6952 - loss: 1.2866 - val_accuracy: 0.6884 - val_loss: 1.3784
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6943 - loss: 1.3596 - val_accuracy: 0.6878 - val_loss: 1.3792
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6949 - loss: 1.2580 - val_accuracy: 0.6884 - val_loss: 1.3797
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6949 - loss: 1.3511 - val_accuracy: 0.6890 - val_loss: 1.3800
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6870 - loss: 1.3666 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6934 - loss: 1.2865 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6788 - loss: 1.4023 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6971 - loss: 1.3054 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6937 - loss: 1.2478 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6972 - loss: 1.2955 - val_accuracy: 0.6884 - val_loss: 1.3810
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6972 - loss: 1.2916 - val_accuracy: 0.6865 - val_loss: 1.3799
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6872 - loss: 1.2593 - val_accuracy: 0.6890 - val_loss: 1.3805
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6958 - loss: 1.3924 - val_accuracy: 0.6871 - val_loss: 1.3806
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7042 - loss: 1.2810 - val_accuracy: 0.6865 - val_loss: 1.3826
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7054 - loss: 1.2482 - val_accuracy: 0.6878 - val_loss: 1.3802
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6968 - loss: 1.2606 - val_accuracy: 0.6884 - val_loss: 1.3806
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7028 - loss: 1.2619 - val_accuracy: 0.6922 - val_loss: 1.3773
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6975 - loss: 1.3048 - val_accuracy: 0.6928 - val_loss: 1.3770

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 84/84 - 0s - 708us/step - accuracy: 0.6867 - loss: 1.3149
# Loss: 1.3149161338806152, Accuracy: 0.6867243051528931

# %% [markdown]
# # Tuner

# %% [markdown]
# # RMSE

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import math 
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
# Define the model
model = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    BatchNormalization(),  # Normalize the activations of the previous layer at each batch
    Dropout(0.3),  # Randomly set a fraction of input units to 0 at each update during training
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(1)  # Output layer
])
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=['accuracy'])
# Model summary to see the architecture
model.summary()
# Fit the model
history = model.fit(X_train_scaled, y_train_encoded, validation_split=0.2, epochs=100, batch_size=32, verbose=1)
# Evaluate the model
y_pred_nn = model.predict(X_test_scaled).flatten()
rmse_nn = np.sqrt(mean_squared_error(y_test_encoded, y_pred_nn))
print(f'Advanced Neural Network RMSE: {rmse_nn}')

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
