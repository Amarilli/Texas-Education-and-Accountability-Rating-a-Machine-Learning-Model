# %%
import pandas as pd
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
import keras_tuner as kt
from kerastuner.tuners import Hyperband
from kerastuner import HyperParameters
import matplotlib.pyplot as plt

# %%
districts = pd.read_csv('Resources/tor20.21.csv')
staar = pd.read_csv('Resources/staar20.21.cleaned.csv')
teacher = pd.read_csv('Resources/teachers_scores20_21.csv')
all_info = pd.read_csv('Resources/DISTRICTS_INFO_2020.21.csv')
staar19 = pd.read_csv('Resources/staar19_20.csv')

# %%
completedf = pd.merge(staar19, all_info, on='DISTRICT NAME', how="inner")

# %%
completedf['Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'] - completedf[' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD']
completedf['Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf['Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y'] - completedf['STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x']
completedf['Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf['Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD'] = completedf['STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y'] - completedf['STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x']
completedf['Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x']
completedf['Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'] = completedf['STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y'] - completedf['STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x']

# %%
completedf.columns.to_list()
# Out:
# ['DISTRICT NAME',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  ' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % WRITING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WRITING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WRITING AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_x',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
#  'STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  'DISTRICT NUMBER',
#  'COUNTY NUMBER AND NAME',
#  'EDUCATION SERVICE CENTER REGION',
#  'DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL NUMBER OF SCHOOLS',
#  'TOTAL STUDENTS',
#  'STUDENTS: % AFRICAN AMERICAN',
#  'STUDENTS: % HISPANIC',
#  'STUDENTS: % WHITE',
#  'STUDENTS: % AMERICAN INDIAN',
#  'STUDENTS: % ASIAN',
#  'STUDENTS: % PACIFIC ISLANDER',
#  'STUDENTS: % TWO OR MORE RACES',
#  'STUDENTS: % ECONOMICALLY DISADVANTAGED',
#  'STUDENTS: % ENGLISH LEARNERS (EL)',
#  'STUDENTS: % SPECIAL EDUCATION',
#  'STUDENTS: % BILINGUAL/ESL EDUCATION',
#  'STUDENTS: % CAREER & TECHNICAL EDUCATION',
#  'STUDENTS: % GIFTED & TALENTED EDUCATION',
#  'ATTENDANCE RATE (2020-21)',
#  'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
#  ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
#  ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
#  'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
#  'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
#  'SAT-AVERAGE SCORE (2021-2020)',
#  'ACT-AVERAGE SCORE (2021-2020)',
#  'TOTAL STAFF FTE',
#  'TOTAL TEACHER FTE',
#  'STAFF: % CENTRAL ADMINISTRATIVE',
#  'STAFF: % SCHOOL ADMINISTRATIVE',
#  'STAFF: % PROFESSIONAL SUPPORT',
#  'STAFF: % TEACHERS',
#  'STAFF: % EDUCATIONAL AIDES',
#  'STAFF: % AUXILIARY',
#  'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
#  'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
#  'AVERAGE SALARY: PROFESSIONAL SUPPORT',
#  'AVERAGE SALARY: TEACHER',
#  'STAFF: % MINORITY',
#  'NUMBER OF STUDENTS PER TOTAL STAFF',
#  'NUMBER OF STUDENTS PER TEACHER',
#  'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'TEACHER: % WITH ADVANCED DEGREES',
#  'TEACHER: TURNOVER RATE',
#  'TEACHER: % AFRICAN AMERICAN',
#  'TEACHER: % HISPANIC',
#  'TEACHER: % WHITE',
#  'TEACHER: % AMERICAN INDIAN',
#  'TEACHER: % ASIAN',
#  'TEACHER: % PACIFIC ISLANDER',
#  'TEACHER: % TWO OR MORE RACES',
#  'TEACHER: % REGULAR EDUCATION',
#  'TEACHER: % SPECIAL EDUCATION',
#  'TEACHER: % COMPENSATORY EDUCATION',
#  'TEACHER: % BILINGUAL/ESL EDUCATION',
#  'TEACHER: % CAREER & TECHNICAL EDUCATION',
#  'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
#  'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
#  'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
#  'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
#  'Total OPERATING AND OTHER REVENUE PER PUPIL',
#  'Total OPERATING REVENUE (2020-21)',
#  'REVENUE: % STATE',
#  'REVENUE: % LOCAL AND OTHER',
#  'REVENUE: % FEDERAL',
#  'TOTAL OTHER REVENUE(2020-21)',
#  'FUND BALANCE (FOR ISDS)',
#  'NET ASSETS (CHARTER SCHOOLS)',
#  'TOTAL ACTUAL EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
#  'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
#  'EXPENDITURE: % INSTRUCTIONAL',
#  'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
#  'EXPENDITURE: % SCHOOL LEADERSHIP',
#  'EXPENDITURE: % PLANT SERVICES',
#  'EXPENDITURE: % OTHER OPERATING',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
#  'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
#  ' EXPENDITURE: % BASIC EDUCATION SERVICES',
#  'EXPENDITURE: % SPECIAL EDUCATION',
#  'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
#  'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
#  'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
#  ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
#  'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
#  'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
#  'EXPENDITURE: % PREKINDERGARTEN',
#  'EXPENDITURE: % UN-ALLOCATED',
#  'DISTRICT SIZE',
#  'COMMUNITY TYPE',
#  'PROPERTY WEALTH',
#  'TAX RATE',
#  'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE']

# %%
completedf = completedf.drop(columns=['DISTRICT NAME',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % WRITING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WRITING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WRITING AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_x',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 'DISTRICT NUMBER',
 'COUNTY NUMBER AND NAME',
 'EDUCATION SERVICE CENTER REGION',
 'TOTAL NUMBER OF SCHOOLS',
 'STUDENTS: % AFRICAN AMERICAN',
 'STUDENTS: % HISPANIC',
 'STUDENTS: % WHITE',
 'STUDENTS: % AMERICAN INDIAN',
 'STUDENTS: % ASIAN',
 'STUDENTS: % PACIFIC ISLANDER',
 'STUDENTS: % TWO OR MORE RACES',
 'STUDENTS: % ECONOMICALLY DISADVANTAGED',
 'STUDENTS: % ENGLISH LEARNERS (EL)',
 'STUDENTS: % SPECIAL EDUCATION',
 'STUDENTS: % BILINGUAL/ESL EDUCATION',
 'STUDENTS: % CAREER & TECHNICAL EDUCATION',
 'STUDENTS: % GIFTED & TALENTED EDUCATION',
 'ANNUAL DROPOUT RATE GR. 9-12 (2020-21)',
 '5-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2020) DISTRICT EXCL',
 ' 6-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2019) DISTRICT EXCL',
 'ANNUAL RHSP/DAP/FHSP-E/FHSP-DLA GRADUATE COUNT (2020-21)',
 'STAAR: % SCIENCE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % SCIENCE AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % SCIENCE AT MASTERS GRADE LEVEL STANDARD_y',
 'STAAR: % SOCIAL STUDIES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 ' STAAR: % SOCIAL STUDIES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % SOCIAL STUDIES AT MASTERS GRADE LEVEL STANDARD',
 ' STAAR: % AFRICAN AMERICAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AFRICAN AMERICAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % HISPANIC AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % HISPANIC AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % WHITE AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % WHITE AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % AMERICAN INDIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % AMERICAN INDIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ASIAN AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ASIAN AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % PACIFIC ISLANDER AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % PACIFIC ISLANDER AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % TWO OR MORE RACES AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % TWO OR MORE RACES AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 ' STAAR: % TWO OR MORE RACES AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'STAAR: % ECONOMICALLY DISADVANTAGED AT MASTERS GRADE LEVEL STANDARD',
 'COLLEGE ADMISSIONS: % TESTED (2020-2021)',
 'COLLEGE ADMISSIONS: % AT/ABOVE CRITERION (2020-2021)',
 'SAT-AVERAGE SCORE (2021-2020)',
 'ACT-AVERAGE SCORE (2021-2020)',
 'TOTAL STAFF FTE',
 'TOTAL TEACHER FTE',
 'STAFF: % CENTRAL ADMINISTRATIVE',
 'STAFF: % SCHOOL ADMINISTRATIVE',
 'STAFF: % PROFESSIONAL SUPPORT',
 'STAFF: % TEACHERS',
 'STAFF: % EDUCATIONAL AIDES',
 'STAFF: % AUXILIARY',
 'AVERAGE SALARY: CENTRAL ADMINISTRATIVE',
 'AVERAGE SALARY: SCHOOL ADMINISTRATIVE',
 'AVERAGE SALARY: PROFESSIONAL SUPPORT',
 'AVERAGE SALARY: TEACHER',
 'STAFF: % MINORITY',
 'NUMBER OF STUDENTS PER TOTAL STAFF',
 'NUMBER OF STUDENTS PER TEACHER',
 'TEACHER: % WITH 5 OR FEWER YEARS OF EXPERIENCE',
 'TEACHER: % WITH ADVANCED DEGREES',
 'TEACHER: TURNOVER RATE',
 'TEACHER: % AFRICAN AMERICAN',
 'TEACHER: % HISPANIC',
 'TEACHER: % WHITE',
 'TEACHER: % AMERICAN INDIAN',
 'TEACHER: % ASIAN',
 'TEACHER: % PACIFIC ISLANDER',
 'TEACHER: % TWO OR MORE RACES',
 'TEACHER: % REGULAR EDUCATION',
 'TEACHER: % SPECIAL EDUCATION',
 'TEACHER: % COMPENSATORY EDUCATION',
 'TEACHER: % BILINGUAL/ESL EDUCATION',
 'TEACHER: % CAREER & TECHNICAL EDUCATION',
 'TEACHER: % OTHER EDUCATION (INCLUDES G & T)',
 'TAXABLE VALUE PER PUPIL (2019 TAX YEAR)',
 'LOCALLY ADOPTED TAX RATE (2020 TAX YEAR)',
 'TOTAL OPERATING AND OTHER REVENUE (2020-21)',
 'Total OPERATING AND OTHER REVENUE PER PUPIL',
 'Total OPERATING REVENUE (2020-21)',
 'REVENUE: % STATE',
 'REVENUE: % LOCAL AND OTHER',
 'REVENUE: % FEDERAL',
 'TOTAL OTHER REVENUE(2020-21)',
 'FUND BALANCE (FOR ISDS)',
 'NET ASSETS (CHARTER SCHOOLS)',
 'TOTAL ACTUAL EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES (2020-21)',
 'TOTAL ACTUAL OPERATING EXPENDITURES PER PUPIL',
 'EXPENDITURE: % INSTRUCTIONAL',
 'EXPENDITURE: % CENTRAL ADMINISTRATIVE',
 'EXPENDITURE: % SCHOOL LEADERSHIP',
 'EXPENDITURE: % PLANT SERVICES',
 'EXPENDITURE: % OTHER OPERATING',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES',
 'TOTAL ACTUAL INSTRUCTIONAL EXPENDITURES PER PUPIL',
 ' EXPENDITURE: % BASIC EDUCATION SERVICES',
 'EXPENDITURE: % SPECIAL EDUCATION',
 'EXPENDITURE: % STATE COMPENSATORY EDUCATION',
 'EXPENDITURE: % BILINGUAL/ESL EDUCATION',
 'EXPENDITURE: % CAREER & TECHNICAL EDUCATION',
 ' EXPENDITURE: % GIFTED & TALENTED EDUCATION',
 'EXPENDITURE: % ATHLETICS/RELATED ACTIVITIES',
 'EXPENDITURE: % HIGH SCHOOL ALLOTMENT',
 'EXPENDITURE: % PREKINDERGARTEN',
 'EXPENDITURE: % UN-ALLOCATED',
 'DISTRICT SIZE',
 'PROPERTY WEALTH',
 'TAX RATE',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_x',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_x',
 ' STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD'])

# %%
completedf.columns.to_list()
# Out:
# ['DISTRICT ACCOUNTABILITY RATINGS',
#  'TOTAL STUDENTS',
#  'ATTENDANCE RATE (2020-21)',
#  '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
#  'ANNUAL GRADUATE COUNT (2020-21)',
#  'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
#  'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
#  'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
#  'TEACHER: AVERAGE YEARS OF EXPERIENCE',
#  'COMMUNITY TYPE',
#  'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
#  'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
#  'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE']

# %%
completedf = pd.get_dummies(completedf, columns=[
 'TOTAL STUDENTS',
 'ATTENDANCE RATE (2020-21)',
 '4-YR LONGITUDINAL GRADUATION RATE (CLASS OF 2021) DISTRICT EXCL',
 'ANNUAL GRADUATE COUNT (2020-21)',
 'STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD_y',
 'STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE_y',
 'STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD_y',
 'TEACHER: AVERAGE YEARS OF EXPERIENCE',
 'COMMUNITY TYPE',
 'Change in STAAR: % ALL SUBJECTS AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % ALL SUBJECTS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ALL SUBJECTS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ELA/READING AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % ELA/READING AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % ELA/READING AT APPROACHES GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % MATHEMATICS AT MASTERS GRADE LEVEL STANDARD',
 'Change in STAAR: % MATHEMATICS AT MEETS GRADE LEVEL STANDARD OR ABOVE',
 'Change in STAAR: % MATHEMATICS AT APPROACHES GRADE LEVEL STANDARD OR ABOVE'])

# %%
completedf = completedf.dropna()

# %%
# Remove 'DISTRICT ACCOUNTABILITY RATINGS' target from features data
X = completedf.drop(columns=['DISTRICT ACCOUNTABILITY RATINGS']) 
y = completedf['DISTRICT ACCOUNTABILITY RATINGS']  

# Split the data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target variables
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (887, 2888)

# %%
# Define the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=2888))
# Add more hidden layers
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=50, activation='relu'))
model.add(tf.keras.layers.Dense(units=10, activation='relu'))

# Add the output layer
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# c:\Users\riahk\anaconda3\envs\geoviews\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 80)             │       231,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │         8,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 244,791 (956.21 KB)
#  Trainable params: 244,791 (956.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train_scaled, y_train_encoded, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5355 - loss: 0.9413 - val_accuracy: 0.5056 - val_loss: 1.1757
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5415 - loss: 0.9440 - val_accuracy: 0.5281 - val_loss: 1.0863
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.7485 - val_accuracy: 0.6798 - val_loss: 1.0433
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8578 - loss: 0.7755 - val_accuracy: 0.6910 - val_loss: 1.0470
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8616 - loss: 0.5917 - val_accuracy: 0.6966 - val_loss: 1.0530
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8582 - loss: 0.8594 - val_accuracy: 0.6966 - val_loss: 1.0563
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.7244 - val_accuracy: 0.6966 - val_loss: 1.0575
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.5850 - val_accuracy: 0.6910 - val_loss: 1.0583
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8653 - loss: 0.7013 - val_accuracy: 0.6966 - val_loss: 1.0593
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8722 - loss: 0.7182 - val_accuracy: 0.6966 - val_loss: 1.0602
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.5822 - val_accuracy: 0.6966 - val_loss: 1.0610
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8616 - loss: 0.5529 - val_accuracy: 0.7022 - val_loss: 1.0617
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8647 - loss: 0.6216 - val_accuracy: 0.7022 - val_loss: 1.0623
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8785 - loss: 0.6521 - val_accuracy: 0.7022 - val_loss: 1.0631
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.6805 - val_accuracy: 0.7022 - val_loss: 1.0638
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8883 - loss: 0.5689 - val_accuracy: 0.7022 - val_loss: 1.0645
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.6225 - val_accuracy: 0.7022 - val_loss: 1.0650
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8559 - loss: 0.7446 - val_accuracy: 0.7022 - val_loss: 1.0655
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8692 - loss: 0.6196 - val_accuracy: 0.7022 - val_loss: 1.0659
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8831 - loss: 0.5852 - val_accuracy: 0.7079 - val_loss: 1.0663
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.6908 - val_accuracy: 0.7022 - val_loss: 1.0667
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8459 - loss: 0.7842 - val_accuracy: 0.7079 - val_loss: 1.0672
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8714 - loss: 0.7032 - val_accuracy: 0.7079 - val_loss: 1.0676
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.7588 - val_accuracy: 0.7079 - val_loss: 1.0680
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.5972 - val_accuracy: 0.7079 - val_loss: 1.0683
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.7203 - val_accuracy: 0.7079 - val_loss: 1.0687
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.6528 - val_accuracy: 0.7079 - val_loss: 1.0690
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8780 - loss: 0.7235 - val_accuracy: 0.7079 - val_loss: 1.0692
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8484 - loss: 0.7262 - val_accuracy: 0.7079 - val_loss: 1.0695
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8593 - loss: 0.6884 - val_accuracy: 0.7079 - val_loss: 1.0699
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8696 - loss: 0.8478 - val_accuracy: 0.7079 - val_loss: 1.0701
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8668 - loss: 0.7390 - val_accuracy: 0.7079 - val_loss: 1.0704
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8619 - loss: 0.7945 - val_accuracy: 0.7079 - val_loss: 1.0707
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8899 - loss: 0.5851 - val_accuracy: 0.7079 - val_loss: 1.0709
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.5323 - val_accuracy: 0.7079 - val_loss: 1.0711
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8720 - loss: 0.7082 - val_accuracy: 0.7079 - val_loss: 1.0713
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.6527 - val_accuracy: 0.7079 - val_loss: 1.0716
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8668 - loss: 0.6546 - val_accuracy: 0.7079 - val_loss: 1.0718
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8784 - loss: 0.6698 - val_accuracy: 0.7079 - val_loss: 1.0720
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8859 - loss: 0.4686 - val_accuracy: 0.7079 - val_loss: 1.0722
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.7877 - val_accuracy: 0.7079 - val_loss: 1.0724
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8818 - loss: 0.6027 - val_accuracy: 0.7079 - val_loss: 1.0726
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8743 - loss: 0.6645 - val_accuracy: 0.7079 - val_loss: 1.0727
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8610 - loss: 0.7190 - val_accuracy: 0.7079 - val_loss: 1.0729
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8758 - loss: 0.6675 - val_accuracy: 0.7079 - val_loss: 1.0731
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8559 - loss: 0.7775 - val_accuracy: 0.7079 - val_loss: 1.0732
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8673 - loss: 0.5734 - val_accuracy: 0.7079 - val_loss: 1.0734
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8770 - loss: 0.6324 - val_accuracy: 0.7079 - val_loss: 1.0736
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8901 - loss: 0.7039 - val_accuracy: 0.7079 - val_loss: 1.0738
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8587 - loss: 0.7579 - val_accuracy: 0.7079 - val_loss: 1.0740
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8631 - loss: 0.6647 - val_accuracy: 0.7079 - val_loss: 1.0741
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8745 - loss: 0.6573 - val_accuracy: 0.7079 - val_loss: 1.0743
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.6317 - val_accuracy: 0.7079 - val_loss: 1.0744
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8805 - loss: 0.5764 - val_accuracy: 0.7079 - val_loss: 1.0745
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8658 - loss: 0.8487 - val_accuracy: 0.7079 - val_loss: 1.0747
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8784 - loss: 0.6551 - val_accuracy: 0.7079 - val_loss: 1.0748
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.7849 - val_accuracy: 0.7079 - val_loss: 1.0749
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8741 - loss: 0.6259 - val_accuracy: 0.7079 - val_loss: 1.0750
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8626 - loss: 0.6444 - val_accuracy: 0.7079 - val_loss: 1.0752
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.8414 - val_accuracy: 0.7079 - val_loss: 1.0753
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8580 - loss: 0.6221 - val_accuracy: 0.7079 - val_loss: 1.0754
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8703 - loss: 0.7511 - val_accuracy: 0.7079 - val_loss: 1.0755
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.4764 - val_accuracy: 0.7079 - val_loss: 1.0756
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.6159 - val_accuracy: 0.7079 - val_loss: 1.0757
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8513 - loss: 0.8936 - val_accuracy: 0.7079 - val_loss: 1.0758
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.8914 - val_accuracy: 0.7079 - val_loss: 1.0759
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.7777 - val_accuracy: 0.7079 - val_loss: 1.0760
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8712 - loss: 0.7825 - val_accuracy: 0.7079 - val_loss: 1.0761
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8309 - loss: 0.9552 - val_accuracy: 0.7079 - val_loss: 1.0762
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8680 - loss: 0.7282 - val_accuracy: 0.7079 - val_loss: 1.0763
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8745 - loss: 0.6520 - val_accuracy: 0.7079 - val_loss: 1.0764
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8578 - loss: 0.8135 - val_accuracy: 0.7079 - val_loss: 1.0765
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8500 - loss: 0.8610 - val_accuracy: 0.7079 - val_loss: 1.0766
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8550 - loss: 0.7704 - val_accuracy: 0.7079 - val_loss: 1.0767
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.6696 - val_accuracy: 0.7079 - val_loss: 1.0768
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8584 - loss: 0.8633 - val_accuracy: 0.7079 - val_loss: 1.0769
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8969 - loss: 0.5482 - val_accuracy: 0.7079 - val_loss: 1.0769
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8658 - loss: 0.6119 - val_accuracy: 0.7079 - val_loss: 1.0770
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.7220 - val_accuracy: 0.7079 - val_loss: 1.0771
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8746 - loss: 0.5993 - val_accuracy: 0.7079 - val_loss: 1.0772
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8703 - loss: 0.6000 - val_accuracy: 0.7079 - val_loss: 1.0773
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.6954 - val_accuracy: 0.7079 - val_loss: 1.0774
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.6949 - val_accuracy: 0.7079 - val_loss: 1.0774
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8849 - loss: 0.5910 - val_accuracy: 0.7079 - val_loss: 1.0775
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8621 - loss: 0.7125 - val_accuracy: 0.7079 - val_loss: 1.0776
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8699 - loss: 0.5901 - val_accuracy: 0.7079 - val_loss: 1.0777
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8784 - loss: 0.6278 - val_accuracy: 0.7079 - val_loss: 1.0777
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.6990 - val_accuracy: 0.7079 - val_loss: 1.0778
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.7597 - val_accuracy: 0.7079 - val_loss: 1.0779
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8730 - loss: 0.4856 - val_accuracy: 0.7079 - val_loss: 1.0780
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8578 - loss: 0.6841 - val_accuracy: 0.7079 - val_loss: 1.0781
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.6710 - val_accuracy: 0.7079 - val_loss: 1.0782
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.6728 - val_accuracy: 0.7079 - val_loss: 1.0782
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8647 - loss: 0.6779 - val_accuracy: 0.7079 - val_loss: 1.0783
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8766 - loss: 0.5882 - val_accuracy: 0.7079 - val_loss: 1.0784
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.8681 - val_accuracy: 0.7079 - val_loss: 1.0785
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.6892 - val_accuracy: 0.7079 - val_loss: 1.0786
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8732 - loss: 0.6261 - val_accuracy: 0.7079 - val_loss: 1.0786
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.7410 - val_accuracy: 0.7079 - val_loss: 1.0787
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8697 - loss: 0.6051 - val_accuracy: 0.7079 - val_loss: 1.0788

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10/10 - 0s - 2ms/step - accuracy: 0.7399 - loss: 0.7313
# Loss: 0.7313106060028076, Accuracy: 0.7398648858070374

# %% [markdown]
# # Tuner

# %% [markdown]
# # RMSE

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import math 
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
# Define the model
model = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    BatchNormalization(),  # Normalize the activations of the previous layer at each batch
    Dropout(0.3),  # Randomly set a fraction of input units to 0 at each update during training
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(1)  # Output layer
])
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=['accuracy'])
# Model summary to see the architecture
model.summary()
# Fit the model
history = model.fit(X_train_scaled, y_train_encoded, validation_split=0.2, epochs=100, batch_size=32, verbose=1)
# Evaluate the model
y_pred_nn = model.predict(X_test_scaled).flatten()
rmse_nn = np.sqrt(mean_squared_error(y_test_encoded, y_pred_nn))
print(f'Advanced Neural Network RMSE: {rmse_nn}')

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
